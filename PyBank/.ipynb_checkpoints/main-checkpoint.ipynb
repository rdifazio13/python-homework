# %%
import pandas as pd
from pathlib import Path

csvpath = Path(r"\Users\bobdi\Desktop\budget_data.csv")
budget_data = pd.read_csv(csvpath)
budget_data.head()
# Out:
#        Date  Profit/Losses
# 0  Jan-2010         867884
# 1  Feb-2010         984655
# 2  Mar-2010         322013
# 3  Apr-2010         -69417
# 4  May-2010         310503

# %%
#The total number of months included in the dataset.
Months = 0

#The net total amount of Profit/Losses over the entire period.
Net_Total = 0

#The average of the changes in Profit/Losses over the entire period.
Average_Change = 0

#The greatest increase in profits (date and amount) over the entire period.
Greatest_Increase = ["", 0]

#The greatest decrease in losses (date and amount) over the entire period.
Greatest_Decrease = ["", 99999999999999999] 

for x in budget_data["Date"]: 
  Months=Months+1
print(Months)

for x in budget_data["Profit/Losses"]: 
  Net_Total=Net_Total+x
print(Net_Total)

Average_Change=budget_data["Profit/Losses"].mean()
print(Average_Change)

net_change = int(row[1]) - prev_net
prev_net = int(row[1])
net_change_list = net_change_list + [net_change] 
month_of_change = month_of_change + [row[0]]

if net_change > greatest_increase[1]:
    greatest_increase[0] = row[0]
    greatest_increase[1] = net_change
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12404/3165305473.py in <module>
#      14 Greatest_Decrease = ["", 99999999999999999]
#      15
# ---> 16 for x in budget_data["Date"]:
#      17   Months=Months+1
#      18 print(Months)
#
# NameError: name 'budget_data' is not defined

# %%
import pandas as pd
from pathlib import Path

csvpath = Path(r"\Users\bobdi\Desktop\budget_data.csv")
budget_data = pd.read_csv(csvpath)
budget_data.head()
# Out:
#        Date  Profit/Losses
# 0  Jan-2010         867884
# 1  Feb-2010         984655
# 2  Mar-2010         322013
# 3  Apr-2010         -69417
# 4  May-2010         310503

# %%
import pandas as pd
from pathlib import Path

csvpath = Path(r"\Users\bobdi\Desktop\budget_data.csv")
budget_data = pd.read_csv(csvpath)
budget_data.head()

#The total number of months included in the dataset.
Months = 0

#The net total amount of Profit/Losses over the entire period.
Net_Total = 0

#The average of the changes in Profit/Losses over the entire period.
Average_Change = 0

#The greatest increase in profits (date and amount) over the entire period.
Greatest_Increase = ["", 0]

#The greatest decrease in losses (date and amount) over the entire period.
Greatest_Decrease = ["", 99999999999999999] 

for x in budget_data["Date"]: 
  Months=Months+1
print(Months)

for x in budget_data["Profit/Losses"]: 
  Net_Total=Net_Total+x
print(Net_Total)

Average_Change=budget_data["Profit/Losses"].mean()
print(Average_Change)

for x in:
net_change = int(x[1]) - prev_net
prev_net = int(x[1])
net_change_list = net_change_list + [net_change] 
month_of_change = month_of_change + [x[0]]

if net_change > greatest_increase[1]:
    greatest_increase[0] = x[0]
    greatest_increase[1] = net_change
# Out:
#   File "C:\Users\bobdi\AppData\Local\Temp/ipykernel_12404/1385319272.py", line 34
#     for x in:
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from pathlib import Path

csvpath = Path(r"\Users\bobdi\Desktop\budget_data.csv")
budget_data = pd.read_csv(csvpath)
budget_data.head()

#The total number of months included in the dataset.
Months = 0

#The net total amount of Profit/Losses over the entire period.
Net_Total = 0

#The average of the changes in Profit/Losses over the entire period.
Average_Change = 0

#The greatest increase in profits (date and amount) over the entire period.
Greatest_Increase = ["", 0]

#The greatest decrease in losses (date and amount) over the entire period.
Greatest_Decrease = ["", 99999999999999999] 

net_change_list = []

month_of_change = []

print("Financial Analysis")
print("-------------------")

for x in budget_data["Date"]: 
  Months=Months+1
print(Months)

for x in budget_data["Profit/Losses"]: 
  Net_Total=Net_Total+x
print(Net_Total)

Average_Change=budget_data["Profit/Losses"].mean()
print(Average_Change)

for x in budget_data:

    if net_change > Greatest_Increase[1]:
        Greatest_Increase[0] = x
        Greatest_Increase[1] = net_change
    print(Greatest_Increase)

    if net_change < Greatest_Decrease[1]:
        Greatest_Decrease[0] = x
        Greatest_Decrease[1] = net_change
    print(Greatest_Decrease)
    
df = pd.read_csv(csvpath)

df['shifter'] = df['Profit/Losses'].shift(1)

df['diff'] = df['Profit/Losses'] - df['shifter']

df1 = df.sort_values(by=['diff'], ascending=True)

print(df1)
# Out:
# Financial Analysis
# -------------------
# 86
# 38382578
# 446309.0465116279
# ['', 0]
# ['Date', 0]
# ['', 0]
# ['Date', 0]
#         Date  Profit/Losses    shifter       diff
# 44  Sep-2013       -1196225   999942.0 -2196167.0
# 78  Jul-2016       -1163797   712961.0 -1876758.0
# 73  Feb-2016       -1100387   650000.0 -1750387.0
# 31  Aug-2012       -1022534   506702.0 -1529236.0
# 63  Apr-2015        -524626   687533.0 -1212159.0
# ..       ...            ...        ...        ...
# 32  Sep-2012         475062 -1022534.0  1497596.0
# 79  Aug-2016         569899 -1163797.0  1733696.0
# 47  Dec-2013        1150461  -687986.0  1838447.0
# 25  Feb-2012        1170593  -755566.0  1926159.0
# 0   Jan-2010         867884        NaN        NaN
#
# [86 rows x 4 columns]
